# %%
from pyspark.sql import SparkSession
import pandas as pd
import glob

# %%
spark = SparkSession.builder.appName("WildChatDataProcessing").getOrCreate()

section_1 = spark.read.parquet('/Users/james/Projects/WildChat/data/WildChatData/0000.parquet')
workfile_1 = section_1.copy()
section_1_sample = workfile_1.sample(frac=0.01, random_state=42)


section_2 = spark.read.parquet('/Users/james/Projects/WildChat/data/WildChatData/0001.parquet')
workfile_2 = section_2.copy()
section_2_sample = workfile_2.sample(frac=0.01, random_state=42)

section_3 = spark.read.parquet('/Users/james/Projects/WildChat/data/WildChatData/0002.parquet')
workfile_3 = section_3.copy()
section_3_sample = workfile_3.sample(frac=0.01, random_state=42)

# %%
section_4 = pd.read_parquet('/Users/james/Projects/WildChat/data/WildChatData/0003.parquet')
workfile_4 = section_4.copy()
section_4_sample = workfile_4.sample(frac=0.01, random_state=42)

section_5 = pd.read_parquet('/Users/james/Projects/WildChat/data/WildChatData/0004.parquet')
workfile_5 = section_5.copy()   
section_5_sample = workfile_5.sample(frac=0.01, random_state=42)

section_6 = pd.read_parquet('/Users/james/Projects/WildChat/data/WildChatData/0005.parquet')
workfile_6 = section_6.copy()
section_6_sample = workfile_6.sample(frac=0.01, random_state=42)

# %%
section_7 = pd.read_parquet('/Users/james/Projects/WildChat/data/WildChatData/0006.parquet')
workfile_7 = section_7.copy()
section_7_sample = workfile_7.sample(frac=0.01, random_state=42)

section_8 = pd.read_parquet('/Users/james/Projects/WildChat/data/WildChatData/0007.parquet')
workfile_8 = section_8.copy()
section_8_sample = workfile_8.sample(frac=0.01, random_state=42)

section_9 = pd.read_parquet('/Users/james/Projects/WildChat/data/WildChatData/0008.parquet')
workfile_9 = section_9.copy()
section_9_sample = workfile_9.sample(frac=0.01, random_state=42)

# %%
section_10 = pd.read_parquet('/Users/james/Projects/WildChat/data/WildChatData/0009.parquet')
workfile_10 = section_10.copy()
section_10_sample = workfile_10.sample(frac=0.01, random_state=42)

section_11 = pd.read_parquet('/Users/james/Projects/WildChat/data/WildChatData/0010.parquet')
workfile_11 = section_11.copy()
section_11_sample = workfile_11.sample(frac=0.01, random_state=42)

section_12 = pd.read_parquet('/Users/james/Projects/WildChat/data/WildChatData/0011.parquet')
workfile_12 = section_12.copy()
section_12_sample = workfile_12.sample(frac=0.01, random_state=42)

# %%
section_13 = pd.read_parquet('/Users/james/Projects/WildChat/data/WildChatData/0012.parquet')
workfile_13 = section_13.copy()
section_13_sample = workfile_13.sample(frac=0.01, random_state=42)

section_14 = pd.read_parquet('/Users/james/Projects/WildChat/data/WildChatData/0013.parquet')
workfile_14 = section_14.copy()
section_14_sample = workfile_14.sample(frac=0.01, random_state=42)

# %%
sample_dataframe = pd.concat([section_1, section_2, section_3, section_4, section_5, section_6, section_7, section_8, section_9, section_10, section_11, section_12, section_13, section_14], ignore_index=True)
